# %%
import numpy as np
import pandas as pd
import random
import csv

# %%
scores = np.random.randint(50,101,(50,5))
scoresfrom = pd.DataFrame(scores,
                          range(1,51),
                          ["國文","數學","英文","自然","社會"])
scoresfrom["總分"] = scoresfrom.sum(1)
scoresfrom["平均"] = scoresfrom.mean(1)
scoresfrom

# %%
frame = pd.DataFrame(
    np.arange(16).reshape((4,4)),
    index=["1)","2)","3)","4)"],
    columns=["A","B","C","D"]
)
display(frame)
#subscript
display(frame["A"])
#locsubscript
display(frame.loc["1)"])
#ilocsubscript
display(frame.iloc[0:3,[0,2]])

# %%
stuscores = pd.DataFrame(pd.read_csv("stuscore.csv"))
stuscores.index = stuscores['姓名']
stuscores = stuscores.iloc[0::,1::]

sum = stuscores.sum(axis=1)
avg = stuscores.mean(axis=1)
stuscores["總分"] = sum
stuscores["平均"] = avg
display(stuscores)
# Out:
#      國文  英文   數學   自然  社會   總分    平均
# 姓名
# 余宗儒  85  90   34   51  30  290  58.0
# 胡芳瑜  45  80   14    0  91  230  46.0
# 劉萬季  12  31   84   73  26  226  45.2
# 劉嘉泰  97  55   62   96  61  371  74.2
# 陳怡容  55  66   58   68  23  270  54.0
# 黃志福  66   6   58   70  77  277  55.4
# 吳俐芷   1  36   17   63  84  201  40.2
# 張雅芬  69  70    5   65  15  224  44.8
# 張家秀  89  71  100   38   0  298  59.6
# 王良斌  41  27   88   81  20  257  51.4
# 蘇婷婷  51   0   14   46  76  187  37.4
# 楊綺芬  82  40   24   24  68  238  47.6
# 黃麗美  28  33    0    2  28   91  18.2
# 賴心怡  31  13   56   68  53  221  44.2
# 唐翊修  70  92   44   50  41  297  59.4
# 林佳人   4  93   55   55  26  233  46.6
# 黃善迪  68  81   17   86  51  303  60.6
# 林玉佩  82  69   72   48  52  323  64.6
# 張雅芬  29  12   92   21   9  163  32.6
# 黃翔杰  69  48   81   18  73  289  57.8
# 王明昇   9  57   62   52   3  183  36.6
# 陳冠霞   0  71   38   19  50  178  35.6
# 陳逸凡  69   0   99   91  83  342  68.4
# 林義皓  71  41   96   53  74  335  67.0
# ...
